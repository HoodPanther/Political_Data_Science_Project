# %%
import os
os.chdir('/home/composersyf/Documents/Political Data Science Project')

# %%
import numpy as np
import pandas as pd
import re

# %%
import glob
all_at_filenames=glob.glob("TwitterData/* -at,*")
persons=[]
for name in all_at_filenames:
    persons.append(name.split(",")[1].split("-")[0])
persons=np.unique(persons)
persons
# Out:
# array(['BernieSanders', 'HillaryClinton', 'JohnKasich', 'SenRubioPress',
#        'SenSanders', 'realDonaldTrump', 'tedcruz'],
#       dtype='<U15')

# %%
person_name_dict={"Donald Trump": "realDonaldTrump",
                 "Hillary Clinton": "HillaryClinton",
                 "Bernie Sanders": ["BernieSanders","SenSanders"],
                 "Ted Cruz": "tedcruz",
                 "John Kasich":"JohnKasich",
                 "Marco Rubio":"SenRubioPress"}

# %% [markdown]
# ## A summary of @realDonaldTrump tweets during on 2016-06-01, as a preliminary exploratory data analysis

# %%
trump_filenames=glob.glob("TwitterData/* -at,realDonaldTrump*2016.06.01*")
all_tweets=[]
all_usernames=[]
for f in trump_filenames:
    with open(f) as file:
        file_texts=file.readlines()
        file_texts=file_texts[1:]
    tweets=[None]*len(file_texts)
    usernames=[None]*len(file_texts)
    for i,text in enumerate(file_texts):
        splitted_text=text.split("\",\"")
        tweets[i]=splitted_text[11]
        usernames[i]=splitted_text[6]
    all_tweets.extend(tweets)
    all_usernames.extend(usernames)
tweets_data=np.array(all_usernames+all_tweets)
tweets_data=tweets_data.reshape(2,len(all_tweets))
tweets_data=tweets_data.T

# %%
#There are some duplicated tweets (with same tweet texts and same UserName), so they need to be removed
tweets_data_df=pd.DataFrame(tweets_data)
print(np.where(tweets_data_df.duplicated()==True))
tweets_data_df=tweets_data_df.drop_duplicates()
# Out:
# (array([   174,    176,   1273,   1306,   1329,   3332,   4215,   6038,
#          7252,  10744,  11036,  11521,  11577,  13052,  13333,  13589,
#         14578,  14598,  14621,  15699,  15790,  15893,  15936,  17934,
#         18823,  21186,  21438,  21524,  22178,  22233,  24384,  24487,
#         24716,  25424,  25690,  27625,  31651,  31707,  32254,  32893,
#         35316,  37489,  40347,  41326,  41392,  42668,  45745,  46695,
#         47723,  50395,  50865,  52688,  52894,  55673,  56841,  57876,
#         58011,  58321,  58335,  58349,  58567,  58606,  58738,  59426,
#         60410,  61603,  63691,  64048,  65022,  65991,  66744,  67355,
#         69884,  71278,  74045,  75419,  77140,  78172,  78423,  79260,
#         79518,  80916,  83035,  87123,  90164,  90276,  91200,  92162,
#         92887,  93155,  93221,  93961,  94050,  94593,  94697,  94788,
#         95664,  96699,  99029,  99292,  99659, 100244, 103592, 103653,
#        104555, 104788, 105134, 105271, 105669, 105753, 106193, 106878,
#        107411, 108188, 108223, 108264, 108383, 109201, 109412, 110460,
#        111137, 112554, 113556, 113830, 114502, 114705, 125324, 128216,
#        130166, 130167, 130170, 130172, 130174, 130175, 130177, 130347,
#        130348, 130349, 130351, 130352, 130353, 130354, 130355, 130356,
#        130357, 130358, 130360, 130362, 130363, 130364, 130365, 130366,
#        130367, 130370, 130414, 130458, 130761, 131227, 131691, 132101,
#        134850, 135567, 136124, 136456, 137176, 137222, 137605, 137732,
#        138488, 139101, 139474, 139494, 141964, 142025, 142030, 143166,
#        143569, 144165, 144181, 144229, 144254, 144326, 144427, 144551,
#        145644, 145843, 146352, 146377, 146378, 146409, 147335, 149914,
#        151114, 152835, 152980, 154287, 157741, 159062, 159160, 159539,
#        161557, 163221, 165213, 165859, 167492, 167513, 167806, 167908,
#        168482, 170093, 173078, 173132, 173143, 173163, 173201, 173524,
#        173829, 174296, 174551, 174556, 175047, 175427, 176564, 178081,
#        179046, 180097, 180099, 180103, 180430, 180681, 181009, 181718,
#        183137, 183258, 185437, 185525, 185842, 186160, 186573, 187651,
#        189940, 192626, 193635, 193772, 195923, 197182, 197197, 199378,
#        200733, 200737, 203185, 203312, 203372, 203549, 203727, 203793,
#        203879, 203949, 203960, 204042, 204071, 210487, 211292, 211298,
#        212030, 213934, 214539, 215604, 216733, 219065, 219141, 219175,
#        219244, 219308, 219344, 219767, 220199, 220482, 220783, 221508,
#        222110, 223507, 224268, 224332, 224364, 224382, 224407, 224578,
#        224592, 224598, 225390, 225957, 226226, 226232, 226248, 226259,
#        226354, 227104, 227133, 227993, 230073, 230218, 230905, 231387,
#        231553, 231798, 232096, 232846, 233049, 233691, 233954, 234573,
#        236214, 236286, 236368, 236387, 236435, 236515, 236527, 237603,
#        237942, 238058, 238064, 238121, 238157, 238171, 238194, 238398,
#        238400, 239039, 239497, 239850, 240117, 240492, 240712, 240910,
#        241160, 241184, 241257, 241282, 241310, 241347, 241404, 242702,
#        242705, 242766, 242830, 242832, 242854, 242856, 242859, 242864,
#        242866, 242874, 242905, 242917, 242981]),)

# %%
tweets_data_df.shape
#Total number of tweets @realDonaldTrump on 06-01-2016 is 242,882
# Out:
# 242882

# %%
from nltk.tokenize import TweetTokenizer

# %% [markdown]
# #### Analyze the hashtags

# %%
tknzr = TweetTokenizer()
hashtag_regex=re.compile("^#")
all_hashtags=[]
for i in range(tweets_data_df.shape[0]):
    tokens=tknzr.tokenize(tweets_data_df.iloc[i,1])
    for token in tokens:
        if hashtag_regex.findall(token)==["#"] and token!="#": #it was found that '#' is not acutally a hashtag, so it should be removed
            all_hashtags.append(token)

#re.search("^\#",tknzr.tokenize(tweets_data_df.iloc[8,1])[5])

# %%
print(len(all_hashtags)) #total number of hashtags used by the all tweets @realDonaldTrump on 06-01-2016
print(len(np.unique(all_hashtags))) #total number of unique hashtags
# Out:
# 99547
# 10908

# %%
from collections import Counter
hashtag_counts=Counter(all_hashtags)
hashtag_counts.most_common(50) #return the 50 most popular hashtags for @realDonaldTrump on 06-01-2016

# %%
#some noticeable hashtags:
#MSM: Mainstream Media
#tcot: "Top Conservatives on Twitter"
#Vets: Veterans
#Hannity: a hashtag closely related to Sean Hannity
#ICYMI: In case you missed it
#fringecandidates: a hashtag closely related to the potential third party presidential candidate Gary Johnson
#dtmag: the abridged hashtag of #TRUMPmagazine
#LDTPoll: ??
#greta: a hashtag closely related to Greta Van Susteren
#pjnet: Patriot Journalist Network
#RollingThunder: Rolling Thunder advocacy group (motorcycle rally)
#DontheCon: Trump is a con man!!!!!
#tlot: Top Libertarians on Twitter
#BestCampaignEver: ??
#2A: Support for all Americans' 2nd Amendment rights to keep and bear arms

# %%
#calculate the total percentage of those top 50 hashtags
counts_sum=0
for i in hashtag_counts.most_common(50):
    counts_sum+=i[1]
print(counts_sum/len(all_hashtags))

#calculate the total percentage of those top 100 hashtags
counts_sum=0
for i in hashtag_counts.most_common(100):
    counts_sum+=i[1]
print(counts_sum/len(all_hashtags))

#calculate the total percentage of those top 20 hashtags
counts_sum=0
for i in hashtag_counts.most_common(20):
    counts_sum+=i[1]
print(counts_sum/len(all_hashtags))
# Out:
# 0.5252795162084242
# 0.6131073764151607
# 0.4179031010477463

# %% [markdown]
# #### Analyze the tweets that contain the @ not exclusively for realDonaldTrump

# %%
tknzr = TweetTokenizer()
at_regex=re.compile("^@")
all_at={}
for i in range(tweets_data_df.shape[0]):
    tokens=tknzr.tokenize(tweets_data_df.iloc[i,1])
    for token in tokens:
        if at_regex.findall(token)==["@"] and token!="@" and token!="@realDonaldTrump" and token!="@RealDonaldTrump": #it was found that '#' is not acutally a hashtag, so it should be removed
            try:
                all_at[i].append(token)
            except KeyError:
                all_at[i]=[token]

# %%
print(len(list(all_at.values())))
print(list(all_at.values())[0:50])
at_opponent=[]
for k in all_at.keys():
    for at in all_at[k]:
        if at.lower() in ['@berniesanders', '@hillaryclinton', '@johnkasich', '@senrubiopress','@sensanders',  '@tedcruz']:
            at_opponent.append(k)
            break
# Out:
# 168648
# [['@SweetzonWheels', '@chrgdup1973', '@realDrumpf'], ['@HillaryClinton'], ['@AdBell45', '@winegirl73'], ['@realDrumpf'], ['@mmfa'], ['@ChatRevolve'], ['@TomLlamasABC', '@ABC'], ['@BBCWorld', '@SenSanders'], ['@AllyTaft', '@Randyh14', '@friedman_h'], ['@briefermadness'], ['@kanyewest', '@POTUS', '@jack'], ['@HillaryClinton'], ['@FriendsofJimmys', '@FrankyLamouche'], ['@Trump_Videos'], ['@TheLastRefuge2', '@NolteNC'], ['@davidaxelrod'], ['@MuncTomm', '@lee_baier', '@scotthwk62'], ['@scapesrus'], ['@starknightz'], ['@peterdaou'], ['@bigop1'], ['@TrumpsGucciGirl'], ['@DanScavino'], ['@chriskyleband', '@FLTrumpTeam'], ['@GovGaryJohnson'], ['@PimpBillClinton', '@LILBTHEBASEDGOD'], ['@ZivaBranstetter', '@samanthavicent', '@MayorBartlett', '@readfrontier'], ['@Destinbeach22'], ['@FoxNews'], ['@SovernNation'], ['@WayneDupreeShow'], ['@Chairmnoomowmow'], ['@kimguilfoyle', '@OutnumberedFNC'], ['@DiamondandSilk'], ['@Me262A1', '@Mischief2You', '@OhmyGalt', '@CalvinTurnquest', '@PalmBeachGOP'], ['@immigrant4trump'], ['@AdBell45'], ['@thehill'], ['@USAforTrump2016'], ['@TomLlamasABC'], ['@NikeNChillemi', '@FrankyLamouche'], ['@HillaryClinton'], ['@FoxNews', '@Al_Baldasaro'], ['@FoxNews', '@Al_Baldasaro'], ['@MichaelCohen212'], ['@jmg66_'], ['@micah_micahk', '@ilipsee'], ['@illustriousJASS', '@cnn'], ['@GovGaryJohnson'], ['@VicenteFoxQue']]

# %%
print(len(at_opponent))
len(at_opponent)/tweets_data_df.shape[0]*100
#~5.18% of the tweets have both @realDonaldTrump and @ other candidates
# Out:
# 12593
# 5.1848222593687465

# %%
at_opponent_2=[]
for k in all_at.keys():
    for at in all_at[k]:
        if at.lower() == '@hillaryclinton':
            at_opponent_2.append(k)
            break

# %%
print(len(at_opponent_2))
len(at_opponent_2)/tweets_data_df.shape[0]*100
#Particularly, ~ 4.41% of the tweets have both @realDonaldTrump and @HillaryClinton
# Out:
# 10703
# 4.406666611770325

# %% [markdown]
# ## A summary of @realDonaldTrump tweets during 2016-05-26 to 2016-06-01

# %%
trump_filenames=glob.glob("TwitterData/* -at,realDonaldTrump*")
trump_filenames_table=[]
for fname in trump_filenames:
    trump_filenames_table.append(fname)
    trump_filenames_table.extend(fname.split("]")[1].split(".")[:3])
trump_filenames_table=np.array(trump_filenames_table)
trump_filenames_table=trump_filenames_table.reshape(len(trump_filenames_table)//4,4)
trump_filenames_table=pd.DataFrame(trump_filenames_table)
trump_filenames_table.columns=["filename","year","month","day"]
trump_filenames_table.day=trump_filenames_table["day"].astype(int)
trump_filenames_table.month=trump_filenames_table["month"].astype(int)
trump_filenames_table.year=trump_filenames_table["year"].astype(int)
trump_filenames_table=trump_filenames_table[(trump_filenames_table.day>=26) | (trump_filenames_table.day==1)]
trump_filenames_table=trump_filenames_table.sort_values(["year","month","day"])
trump_filenames_table
# Out:
#                                               filename  year  month  day
# 14   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 15   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 53   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 73   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 110  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 111  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 112  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 130  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 137  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 149  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 172  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 183  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 187  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 198  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 234  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 236  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 238  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   26
# 12   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 21   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 58   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 62   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 64   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 69   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 78   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 80   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 100  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 103  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 104  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 113  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# 147  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   27
# ..                                                 ...   ...    ...  ...
# 231  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   30
# 254  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   30
# 2    TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 8    TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 34   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 43   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 44   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 88   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 101  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 119  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 145  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 162  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 186  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 189  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      5   31
# 9    TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 10   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 23   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 25   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 31   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 71   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 74   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 82   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 91   TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 136  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 175  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 184  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 192  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 196  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 212  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
# 218  TwitterData/[ BATCH -at,realDonaldTrump-STATUS...  2016      6    1
#
# [106 rows x 4 columns]

# %%
days=np.unique(trump_filenames_table.day)
total_tweet_counts={}
hashtag_counts={}
at_opponent_counts_1={}
at_opponent_counts_2={}

for d in days: #loop through the entire week, on a daily basis
    fnames=np.array(trump_filenames_table[trump_filenames_table.day==d].iloc[:,0])
    all_tweets=[]
    all_usernames=[]
    for f in fnames:
        with open(f) as file:
            file_texts=file.readlines()
            file_texts=file_texts[1:]
        tweets=[None]*len(file_texts)
        usernames=[None]*len(file_texts)
        for i,text in enumerate(file_texts):
            splitted_text=text.split("\",\"")
            tweets[i]=splitted_text[11]
            usernames[i]=splitted_text[6]
        all_tweets.extend(tweets)
        all_usernames.extend(usernames)
    tweets_data=np.array(all_usernames+all_tweets)
    tweets_data=tweets_data.reshape(2,len(all_tweets))
    tweets_data=tweets_data.T
    #remove duplicates
    tweets_data_df=pd.DataFrame(tweets_data)
    tweets_data_df=tweets_data_df.drop_duplicates()
    total_tweet_counts[str(d)]=tweets_data_df.shape[0]
    
    #NLP: tokenize; counting number of distinct hashtags
    tknzr = TweetTokenizer()
    hashtag_regex=re.compile("^#")
    all_hashtags=[]
    for i in range(tweets_data_df.shape[0]):
        tokens=tknzr.tokenize(tweets_data_df.iloc[i,1])
        for token in tokens:
            if hashtag_regex.findall(token)==["#"] and token!="#": #it was found that '#' is not acutally a hashtag, so it should be removed
                all_hashtags.append(token)
    hashtag_counts[str(d)]=Counter(all_hashtags[:])
    
    tknzr = TweetTokenizer()
    at_regex=re.compile("^@")
    all_at={}
    #count the number of tweets that contain both @realDonaldTrump and @ other candidates (particularly @HillaryClinton)
    for i in range(tweets_data_df.shape[0]):
        tokens=tknzr.tokenize(tweets_data_df.iloc[i,1])
        for token in tokens:
            if at_regex.findall(token)==["@"] and token!="@" and token!="@realDonaldTrump" and token!="@RealDonaldTrump": #it was found that '#' is not acutally a hashtag, so it should be removed
                try:
                    all_at[i].append(token)
                except KeyError:
                    all_at[i]=[token]
    at_opponent_counts=0
    for k in all_at.keys():
        for at in all_at[k]:
            if at.lower() in ['@berniesanders', '@hillaryclinton','@johnkasich','@senrubiopress','@sensanders','@tedcruz']:
                at_opponent_counts+=1
                break
    at_opponent_counts_1[d]=at_opponent_counts
    at_opponent_counts=0
    for k in all_at.keys():
        for at in all_at[k]:
            if at.lower() == '@hillaryclinton':
                at_opponent_counts+=1
                break
    at_opponent_counts_2[d]=at_opponent_counts

# %%
total_tweet_counts #daily total tweet counts
# Out:
# {'1': 242882,
#  '26': 251465,
#  '27': 300386,
#  '28': 221817,
#  '29': 183855,
#  '30': 183892,
#  '31': 185945}

# %%
at_opponent_counts_1
# Out:
# {1: 12593, 26: 22713, 27: 48702, 28: 38140, 29: 14886, 30: 13811, 31: 7703}

# %%
at_opponent_counts_2
# Out:
# {1: 10703, 26: 15020, 27: 11787, 28: 10061, 29: 6291, 30: 9307, 31: 4962}

# %%
sum(at_opponent_counts_1.values())/sum(total_tweet_counts.values())*100
#10.1% of the tweets have both @realDonaldTrump and @ other candiates
# Out:
# 10.097042366717996

# %%
sum(at_opponent_counts_2.values())/sum(total_tweet_counts.values())*100
#4.3% of the tweets have both @realDonaldTrump and @HillaryClinton
# Out:
# 4.338885343787773

# %%
total_hashtag_counts=Counter([])
for v in hashtag_counts.values():
    total_hashtag_counts=total_hashtag_counts+v
print(total_hashtag_counts.most_common(50))
sum_of_hashtag_counts=0
for v in total_hashtag_counts.values():
    sum_of_hashtag_counts+=v
print('\n')
print(sum_of_hashtag_counts) #sum of all hashtag counts

#top 50 hashtags
sum_of_hashtag_counts_top=0
for v in total_hashtag_counts.most_common(50):
    sum_of_hashtag_counts_top+=v[1]
print('\n')
print(sum_of_hashtag_counts_top/sum_of_hashtag_counts)

#top 20 hashtags
sum_of_hashtag_counts_top=0
for v in total_hashtag_counts.most_common(20):
    sum_of_hashtag_counts_top+=v[1]
print(sum_of_hashtag_counts_top/sum_of_hashtag_counts)

#top 100 hashtags
sum_of_hashtag_counts_top=0
for v in total_hashtag_counts.most_common(100):
    sum_of_hashtag_counts_top+=v[1]
print(sum_of_hashtag_counts_top/sum_of_hashtag_counts)
# Out:
# [('#Trump2016', 97663), ('#ChickenTrump', 40357), ('#MakeAmericaGreatAgain', 36114), ('#TrumpTrain', 27608), ('#MAGA', 23984), ('#Trump', 13674), ('#BernieTrumpDebate', 11870), ('#NeverTrump', 10644), ('#RollingThunder', 8541), ('#FeelTheBern', 6024), ('#NeverHillary', 5736), ('#TeamTrump', 5538), ('#CrookedHillary', 5486), ('#tcot', 5448), ('#TRUMP', 5287), ('#dtmag', 4672), ('#2A', 4518), ('#veterans', 3649), ('#MeetTheTrumps', 3586), ('#AmericaFirst', 3557), ('#TrumpRally', 3528), ('#GOP', 3437), ('#VoteTrump', 3398), ('#SDTrumpRally', 3289), ('#MemorialDay2016', 3266), ('#MemorialDayWeekend', 3259), ('#NRA', 3104), ('#POTUS', 2666), ('#MemorialDay', 2517), ('#trump', 2481), ('#WhinyLittleBitch', 2445), ('#VoteTrump2016', 2416), ('#WomenForTrump', 2371), ('#MSM', 2250), ('#Trump2', 2175), ('#DonaldTrump', 2137), ('#LatinosForTrump', 2065), ('#Hillary', 2051), ('#AlwaysTrump', 2015), ('#LESM', 1948), ('#HillaryClinton', 1939), ('#nevertrump', 1926), ('#Anaheim', 1918), ('#trump2016', 1918), ('#CAPrimary', 1907), ('#ImWithHer', 1888), ('#MDW', 1872), ('#Hannity', 1863), ('#Vets', 1778), ('#DonTheCon', 1657)]
#
#
# 736714
#
#
# 0.5367618913173905
# 0.43973102180764856
# 0.6164861805259572

# %%
date_dict={"1":"2016-06-01","26":"2016-05-26","27":"2016-05-27","28":"2016-05-28","29":"2016-05-29",
          "30":"2016-05-30","31":"2016-05-31"}
date_dict_2={"1":1,"26":26,"27":27,"28":28,"29":29,
            "30":30,"31":31}

for d in sorted(hashtag_counts.keys()):
    print(date_dict[d])
    print(hashtag_counts[d].most_common(50))
# Out:
# 2016-06-01
# [('#Trump2016', 11753), ('#MakeAmericaGreatAgain', 4274), ('#MAGA', 3839), ('#TrumpTrain', 2625), ('#Trump', 2124), ('#veterans', 2087), ('#NeverTrump', 1983), ('#MSM', 1706), ('#tcot', 1501), ('#TrumpPressConference', 1430), ('#Vets', 1325), ('#Hannity', 1273), ('#CrookedHillary', 864), ('#ICYMI', 860), ('#ChickenTrump', 793), ('#Veterans', 742), ('#NeverHillary', 653), ('#fringecandidates', 645), ('#trump', 571), ('#TRUMP', 553), ('#dtmag', 504), ('#LDTPoll', 482), ('#greta', 473), ('#VoteTrump', 443), ('#pjnet', 435), ('#GOP', 419), ('#trump2016', 413), ('#RollingThunder', 402), ('#EndCommonCore', 382), ('#nevertrump', 378), ('#VoteTrump2016', 377), ('#DonaldTrump', 371), ('#DonTheCon', 353), ('#DumpTrump', 350), ('#Election2016', 348), ('#TrumpUniversity', 339), ('#NewMexico', 324), ('#Massachusetts', 319), ('#2ndAmendment', 318), ('#gayrights', 313), ('#CAforTrump', 311), ('#tlot', 310), ('#CNN', 307), ('#Concerned', 304), ('#AlwaysTrump', 296), ('#BestCampaignEver', 289), ('#2A', 288), ('#AmericaFirst', 286), ('#USA', 280), ('#HillaryClinton', 275)]
# 2016-05-26
# [('#Trump2016', 12237), ('#MakeAmericaGreatAgain', 7566), ('#TrumpTrain', 5125), ('#MAGA', 3780), ('#Trump', 1666), ('#NeverTrump', 1520), ('#TrumpRally', 1392), ('#CrookedHillary', 1377), ('#Anaheim', 1268), ('#NeverHillary', 996), ('#WomenForTrump', 698), ('#LatinosForTrump', 656), ('#POTUS', 654), ('#BernieTrumpDebate', 625), ('#dtmag', 623), ('#AmericaFirst', 592), ('#tcot', 588), ('#2A', 558), ('#California', 541), ('#VoteTrump', 505), ('#FeelTheBern', 499), ('#WomenUnited4Trump', 458), ('#CA', 454), ('#TRUMP', 445), ('#StillWinning', 430), ('#RedNationRising', 425), ('#GOP', 420), ('#BuildTheWall', 409), ('#trump', 407), ('#WeakDonald', 390), ('#Trum', 386), ('#DonTheCon', 370), ('#SCOTUS', 360), ('#BTS', 357), ('#WomenBusinessLeadersforTrump', 356), ('#ImWithHer', 352), ('#Hillary', 341), ('#nevertrump', 338), ('#CAPrimary', 332), ('#trojanhorse', 329), ('#trumptrain', 325), ('#TheWall', 321), ('#Tr', 314), ('#HillaryClinton', 312), ('#LouDobbs', 286), ('#DonaldTrump', 285), ('#Dobbs', 276), ('#infowars', 274), ('#Women4Trump', 261), ('#NRA', 252)]
# 2016-05-27
# [('#Trump2016', 24843), ('#MakeAmericaGreatAgain', 7890), ('#TrumpTrain', 7072), ('#MAGA', 6225), ('#BernieTrumpDebate', 6193), ('#Trump', 3420), ('#MeetTheTrumps', 2973), ('#TeamTrump', 2008), ('#Trump2', 1681), ('#2A', 1630), ('#NeverTrump', 1561), ('#GOP', 1438), ('#FeelTheBern', 1373), ('#NRA', 1338), ('#GUNS', 1238), ('#tcot', 1177), ('#LESM', 1083), ('#AmericaFirst', 1010), ('#dtmag', 935), ('#NeverHillary', 840), ('#CrookedHillary', 797), ('#HillaryClinton', 791), ('#POTUS', 777), ('#AlwaysTrump', 767), ('#1237', 699), ('#TrumpForceOne', 689), ('#WomenForTrump', 637), ('#VoteTrump', 613), ('#president', 573), ('#GUILTY', 561), ('#disgustingdonald', 518), ('#BTS', 514), ('#TrumpRally', 509), ('#TheFive', 501), ('#SlowAndTell', 495), ('#trump2016', 465), ('#FoxNews', 418), ('#LatinosForTrump', 411), ('#Bernie', 410), ('#1238', 405), ('#trump', 404), ('#VoteTrump2016', 396), ('#DonaldTrump', 395), ('#WhiteHouse', 370), ('#Hillary', 369), ('#California', 365), ('#PresidentTrump', 353), ('#WomenUnited4Trump', 351), ('#Anaheim', 331), ('#ThursdayThoughts', 325)]
# 2016-05-28
# [('#ChickenTrump', 27188), ('#Trump2016', 20562), ('#MakeAmericaGreatAgain', 7651), ('#TrumpTrain', 4439), ('#BernieTrumpDebate', 3558), ('#MAGA', 3290), ('#FeelTheBern', 2929), ('#SDTrumpRally', 2449), ('#TeamTrump', 1892), ('#Trump', 1548), ('#NeverTrump', 1288), ('#SanDiego', 1103), ('#ColonelSanders', 972), ('#TrumpRally', 955), ('#2A', 932), ('#chickentrump', 792), ('#WhinyLittleBitch', 753), ('#LESM', 699), ('#ChickenDonald', 693), ('#tcot', 690), ('#ChickenHillary', 664), ('#NeverHillary', 624), ('#NRA', 559), ('#AmericaFirst', 515), ('#dtmag', 514), ('#ChickenedOut', 493), ('#CrookedHillary', 471), ('#MLB', 459), ('#BernieSanders', 459), ('#NHL', 459), ('#DonaldDucksDebate', 445), ('#GOP', 441), ('#ChickenT', 424), ('#Hillary', 411), ('#LDTPoll', 409), ('#VoteTrump', 406), ('#CowardlyDonald', 398), ('#MeetTheTrumps', 398), ('#HUGE', 396), ('#Fresno', 392), ('#TCOT', 371), ('#Bernie', 368), ('#DonaldDucked', 360), ('#whinylittlebitch', 351), ('#SandersTrumpDebate', 350), ('#MemorialDayWeekend', 347), ('#TheWall', 337), ('#MemorialDay', 326), ('#BernieOrBust', 325), ('#TrumpForceOne', 320)]
# 2016-05-29
# [('#Trump2016', 10616), ('#ChickenTrump', 8810), ('#TrumpTrain', 4310), ('#MakeAmericaGreatAgain', 2795), ('#MAGA', 2447), ('#Trump', 1528), ('#NeverTrump', 1367), ('#WhinyLittleBitch', 1102), ('#BernieTrumpDebate', 978), ('#RollingThunder', 971), ('#dtmag', 894), ('#HonorThem', 868), ('#hereos', 867), ('#WashDC', 864), ('#TeamTrump', 815), ('#NYC', 712), ('#SDTrumpRally', 686), ('#ChickenedOut', 667), ('#FeelTheBern', 635), ('#NeverHillary', 578), ('#AmericaFirst', 575), ('#chickentrump', 557), ('#tcot', 497), ('#TrumpRally', 465), ('#whinylittlebitch', 440), ('#VoteTrump', 420), ('#MemorialDayWeekend', 400), ('#2A', 392), ('#CrookedHillary', 366), ('#VoteTrump2016', 347), ('#MakeAmerica', 335), ('#CAforTrump', 326), ('#trump', 313), ('#TRUMP', 298), ('#ChickenHillary', 292), ('#WakeUpAmerica', 263), ('#NRA', 262), ('#POTUS', 260), ('#Biafra', 258), ('#WomenForTrump', 250), ('#RealTime', 250), ('#ImWithHer', 249), ('#MemorialDay', 243), ('#RealTalk', 241), ('#DonaldTrump', 237), ('#TCOT', 230), ('#LatinosForTrump', 229), ('#CAPrimary', 227), ('#TRUMP2016', 227), ('#AMERICA', 222)]
# 2016-05-30
# [('#Trump2016', 8001), ('#RollingThunder', 5356), ('#MakeAmericaGreatAgain', 3033), ('#ChickenTrump', 2372), ('#MAGA', 2321), ('#TrumpTrain', 2253), ('#MemorialDayWeekend', 1773), ('#Trump', 1706), ('#NeverHillary', 1460), ('#NeverTrump', 1351), ('#MDW', 1264), ('#CrookedHillary', 1058), ('#MemorialDay', 828), ('#SyrianRefugee', 735), ('#veterans', 643), ('#VoteTrump2016', 618), ('#tcot', 612), ('#BikersForTrump', 612), ('#TCOT', 542), ('#trump2016', 517), ('#2A', 516), ('#dtmag', 479), ('#LegalizeFreedom', 441), ('#NRA', 436), ('#Bikers4Trump', 427), ('#VoteTrump', 418), ('#military', 395), ('#foxnews', 353), ('#HonorThem', 351), ('#hereos', 347), ('#BernieTrumpDebate', 344), ('#WashDC', 344), ('#rollingthunder', 344), ('#realdonaldtrump', 325), ('#Hillary', 315), ('#army', 297), ('#trump', 294), ('#GOP', 292), ('#airforce', 291), ('#navy', 291), ('#usmc', 281), ('#FallenHeroes', 281), ('#Kamikazes', 278), ('#Bernie', 272), ('#AmericaFirst', 268), ('#nevertrump', 266), ('#FeelTheBern', 260), ('#greta', 259), ('#USA', 254), ('#DonaldTrump', 249)]
# 2016-05-31
# [('#Trump2016', 9651), ('#TRUMP', 3424), ('#MemorialDay2016', 3111), ('#MakeAmericaGreatAgain', 2905), ('#MAGA', 2082), ('#TrumpTrain', 1784), ('#Trump', 1682), ('#RollingThunder', 1651), ('#NeverTrump', 1574), ('#ChickenTrump', 1113), ('#WeAreBetterThanThis', 729), ('#dtmag', 723), ('#MemorialDay', 684), ('#BikersForTrump', 611), ('#VoteTrump', 593), ('#NeverHillary', 585), ('#CrookedHillary', 553), ('#MemorialDayWeekend', 527), ('#veterans', 407), ('#tcot', 383), ('#CAPrimary', 380), ('#MDW', 368), ('#proudamerican', 354), ('#TrumpActuallySaidThat', 315), ('#NJPrimary', 313), ('#AmericaFirst', 311), ('#DonaldTrump', 298), ('#Hillary', 296), ('#FacePalm', 292), ('#WomenForTrump', 262), ('#TeamTrump', 256), ('#Dobbs', 255), ('#feelthebern', 255), ('#LatinosForTrump', 250), ('#GonzaloCuriel', 249), ('#trump', 246), ('#CrookedJudge', 244), ('#nevertrump', 241), ('#AlwaysTrump', 233), ('#Biafrans', 230), ('#DonTheCon', 228), ('#TCOT', 216), ('#GOP', 209), ('#POTUS', 203), ('#2A', 202), ('#America', 199), ('#VoteTrumpUSA', 182), ('#FeelTheBern', 177), ('#USA', 175), ('#BiafraHeroesday', 165)]

# %% [markdown]
# ## A summary of @HillaryClinton tweets during 2016-05-26 to 2016-06-01

# %%
clinton_filenames=glob.glob("TwitterData/* -at,HillaryClinton*")
clinton_filenames_table=[]
for fname in clinton_filenames:
    clinton_filenames_table.append(fname)
    clinton_filenames_table.extend(fname.split("]")[1].split(".")[:3])
clinton_filenames_table=np.array(clinton_filenames_table)
clinton_filenames_table=clinton_filenames_table.reshape(len(clinton_filenames_table)//4,4)
clinton_filenames_table=pd.DataFrame(clinton_filenames_table)
clinton_filenames_table.columns=["filename","year","month","day"]
clinton_filenames_table.day=clinton_filenames_table["day"].astype(int)
clinton_filenames_table.month=clinton_filenames_table["month"].astype(int)
clinton_filenames_table.year=clinton_filenames_table["year"].astype(int)
clinton_filenames_table=clinton_filenames_table[(clinton_filenames_table.day>=26) | (clinton_filenames_table.day==1)]
clinton_filenames_table=clinton_filenames_table.sort_values(["year","month","day"])
clinton_filenames_table
# Out:
#                                               filename  year  month  day
# 34   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   26
# 61   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   26
# 102  TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   26
# 106  TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   26
# 22   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 39   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 55   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 73   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 74   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 82   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 9    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 18   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 66   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 75   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 109  TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 0    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 21   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 50   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 51   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 91   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 1    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 27   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 28   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 77   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 79   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 97   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 6    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 7    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 23   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 43   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 19   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 24   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 25   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 68   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 89   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 105  TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1

# %%
days=np.unique(clinton_filenames_table.day)
total_tweet_counts_2={}
hashtag_counts_2={}
clinton_at_opponent_counts_1={}
clinton_at_opponent_counts_2={}
for d in days:
    fnames=np.array(clinton_filenames_table[clinton_filenames_table.day==d].iloc[:,0])
    all_tweets=[]
    all_usernames=[]
    for f in fnames:
        with open(f) as file:
            file_texts=file.readlines()
            file_texts=file_texts[1:]
        tweets=[None]*len(file_texts)
        usernames=[None]*len(file_texts)
        for i,text in enumerate(file_texts):
            splitted_text=text.split("\",\"")
            tweets[i]=splitted_text[11]
            usernames[i]=splitted_text[6]
        all_tweets.extend(tweets)
        all_usernames.extend(usernames)
    tweets_data=np.array(all_usernames+all_tweets)
    tweets_data=tweets_data.reshape(2,len(all_tweets))
    tweets_data=tweets_data.T
    #remove duplicates
    tweets_data_df=pd.DataFrame(tweets_data)
    tweets_data_df=tweets_data_df.drop_duplicates()
    total_tweet_counts_2[str(d)]=tweets_data_df.shape[0]
    
    #NLP: tokenize; counting number of distinct hashtags
    tknzr = TweetTokenizer()
    hashtag_regex=re.compile("^#")
    all_hashtags=[]
    for i in range(tweets_data_df.shape[0]):
        tokens=tknzr.tokenize(tweets_data_df.iloc[i,1])
        for token in tokens:
            if hashtag_regex.findall(token)==["#"] and token!="#": #it was found that '#' is not acutally a hashtag, so it should be removed
                all_hashtags.append(token)
    hashtag_counts_2[str(d)]=Counter(all_hashtags[:])
    
    tknzr = TweetTokenizer()
    at_regex=re.compile("^@")
    all_at={}
    #count the number of tweets that contain both @realDonaldTrump and @ other candidates (particularly @HillaryClinton)
    for i in range(tweets_data_df.shape[0]):
        tokens=tknzr.tokenize(tweets_data_df.iloc[i,1])
        for token in tokens:
            if at_regex.findall(token)==["@"] and token!="@" and token.lower()!="@hillaryclinton": #it was found that '#' is not acutally a hashtag, so it should be removed
                try:
                    all_at[i].append(token)
                except KeyError:
                    all_at[i]=[token]
    at_opponent_counts=0
    for k in all_at.keys():
        for at in all_at[k]:
            if at.lower() in ['@berniesanders', '@realdonaldtrump','@johnkasich','@senrubiopress','@sensanders','@tedcruz']:
                at_opponent_counts+=1
                break
    clinton_at_opponent_counts_1[d]=at_opponent_counts
    at_opponent_counts=0
    for k in all_at.keys():
        for at in all_at[k]:
            if at.lower() == '@realdonaldtrump':
                at_opponent_counts+=1
                break
    clinton_at_opponent_counts_2[d]=at_opponent_counts

# %%
total_tweet_counts_2 #daily total tweet counts
# Out:
# {'1': 75397,
#  '26': 43815,
#  '27': 91239,
#  '28': 67673,
#  '29': 51439,
#  '30': 52673,
#  '31': 53127}

# %%
clinton_at_opponent_counts_1
# Out:
# {1: 15415, 26: 10498, 27: 16273, 28: 14071, 29: 9476, 30: 12735, 31: 8497}

# %%
clinton_at_opponent_counts_2
# Out:
# {1: 10530, 26: 7294, 27: 11653, 28: 10013, 29: 6328, 30: 9264, 31: 4923}

# %%
sum(clinton_at_opponent_counts_1.values())/sum(total_tweet_counts_2.values())*100
#20.0% of the tweets have both @HillaryClinton and @ other candiates
# Out:
# 19.975284992064093

# %%
sum(clinton_at_opponent_counts_2.values())/sum(total_tweet_counts_2.values())*100
#13.8% of the tweets have both @HillaryClinton and @realDonaldTrump
# Out:
# 13.782751405149266

# %%
total_hashtag_counts_2=Counter([])
for v in hashtag_counts_2.values():
    total_hashtag_counts_2=total_hashtag_counts_2+v
print(total_hashtag_counts_2.most_common(50))
sum_of_hashtag_counts_2=0
for v in total_hashtag_counts_2.values():
    sum_of_hashtag_counts_2+=v
print(sum_of_hashtag_counts_2) #sum of all hashtag counts

#top 50 hashtags
sum_of_hashtag_counts_top_2=0
for v in total_hashtag_counts_2.most_common(50):
    sum_of_hashtag_counts_top_2+=v[1]
print(sum_of_hashtag_counts_top_2/sum_of_hashtag_counts_2)

#top 20 hashtags
sum_of_hashtag_counts_top_2=0
for v in total_hashtag_counts_2.most_common(20):
    sum_of_hashtag_counts_top_2+=v[1]
print(sum_of_hashtag_counts_top_2/sum_of_hashtag_counts_2)

#top 100 hashtags
sum_of_hashtag_counts_top_2=0
for v in total_hashtag_counts_2.most_common(100):
    sum_of_hashtag_counts_top_2+=v[1]
print(sum_of_hashtag_counts_top_2/sum_of_hashtag_counts_2)
# Out:
# [('#ImWithHer', 24261), ('#FeelTheBern', 7348), ('#Trump2016', 6248), ('#NeverHillary', 6153), ('#HillaryClinton', 4674), ('#DropOutBernie', 4491), ('#MAGA', 4207), ('#CrookedHillary', 3966), ('#Hillary2016', 3927), ('#DropOutHillary', 3915), ('#BernieTrumpDebate', 3880), ('#ShesWithUs', 3757), ('#CAPrimary', 3480), ('#BernieSanders', 3194), ('#BernieOrBust', 3061), ('#HRCIsOurNominee', 2898), ('#NEVERTRUMP', 2737), ('#LOVETRUMPSHATE', 2714), ('#SallyRideDay', 2664), ('#Trump', 2540), ('#2A', 2480), ('#GOP', 2443), ('#CaliforniaPrimary', 2440), ('#ChickenTrump', 2431), ('#Benghazi', 2317), ('#GOPdebate', 2317), ('#TBT', 2273), ('#Dems', 2170), ('#Republicans', 2161), ('#Lovetrumpshate', 2118), ('#MOMS', 2117), ('#GUNS', 1663), ('#NRA', 1655), ('#moneygrubber', 1461), ('#SelfServingSa', 1392), ('#tcot', 1302), ('#imwithher', 1213), ('#NeverTrump', 1202), ('#MakeAmericaGreatAgain', 1104), ('#Hillary', 1031), ('#HillaryForPrison2016', 1030), ('#ChickenHillary', 949), ('#FeeltheBern', 881), ('#HillYes', 870), ('#TrumpTrain', 861), ('#HillaryForPrison', 844), ('#MoneyGrubber', 829), ('#UAW', 800), ('#Election2016', 795), ('#UniteBlue', 790)]
# 262754
# 0.555858331366982
# 0.3810217922467403
# 0.6440739246595675

# %%
clinton_filenames=glob.glob("TwitterData/* -at,HillaryClinton*")
clinton_filenames_table=[]
for fname in clinton_filenames:
    clinton_filenames_table.append(fname)
    clinton_filenames_table.extend(fname.split("]")[1].split(".")[:3])
clinton_filenames_table=np.array(clinton_filenames_table)
clinton_filenames_table=clinton_filenames_table.reshape(len(clinton_filenames_table)//4,4)
clinton_filenames_table=pd.DataFrame(clinton_filenames_table)
clinton_filenames_table.columns=["filename","year","month","day"]
clinton_filenames_table.day=clinton_filenames_table["day"].astype(int)
clinton_filenames_table.month=clinton_filenames_table["month"].astype(int)
clinton_filenames_table.year=clinton_filenames_table["year"].astype(int)
clinton_filenames_table=clinton_filenames_table.sort_values(["year","month","day"])
clinton_filenames_table
# Out:
#                                               filename  year  month  day
# 13   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   19
# 60   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   19
# 69   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   19
# 92   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   19
# 2    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 3    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 8    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 10   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 15   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 16   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 17   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 20   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 26   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 31   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 32   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 33   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 35   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 36   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 44   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 45   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 54   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 56   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 62   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 64   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 65   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 67   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 71   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 72   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 76   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# 83   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   20
# ..                                                 ...   ...    ...  ...
# 55   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 73   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 74   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 82   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   27
# 9    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 18   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 66   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 75   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 109  TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   28
# 0    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 21   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 50   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 51   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 91   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   29
# 1    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 27   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 28   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 77   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 79   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 97   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   30
# 6    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 7    TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 23   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 43   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      5   31
# 19   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 24   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 25   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 68   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 89   TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
# 105  TwitterData/[ BATCH -at,HillaryClinton-STATUS]...  2016      6    1
#
# [110 rows x 4 columns]

# %%
np.unique(clinton_filenames_table.day)
# Out:
# array([ 1, 19, 20, 24, 25, 26, 27, 28, 29, 30, 31])

# %%
sanders_filenames_1=glob.glob("TwitterData/* -at,BernieSanders*")
sanders_filenames_1=glob.glob("TwitterData/* -at,SenSanders*")
sanders_filenames_table=[]
for fname in sanders_filenames:
    sanders_filenames_table.append(fname)
    sanders_filenames_table.extend(fname.split("]")[1].split(".")[:3])
sanders_filenames_table=np.array(sanders_filenames_table)
sanders_filenames_table=sanders_filenames_table.reshape(len(sanders_filenames_table)//4,4)
sanders_filenames_table=pd.DataFrame(sanders_filenames_table)
sanders_filenames_table.columns=["filename","year","month","day"]
sanders_filenames_table.day=sanders_filenames_table["day"].astype(int)
sanders_filenames_table.month=sanders_filenames_table["month"].astype(int)
sanders_filenames_table.year=sanders_filenames_table["year"].astype(int)
sanders_filenames_table=sanders_filenames_table.sort_values(["year","month","day"])
sanders_filenames_table
# Out:
#                                               filename  year  month  day
# 47   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   19
# 53   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   19
# 67   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   19
# 69   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   19
# 91   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   19
# 96   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   19
# 98   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   19
# 113  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   19
# 140  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   19
# 146  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   19
# 20   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 35   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 37   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 38   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 40   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 41   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 42   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 44   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 46   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 49   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 52   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 55   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 57   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 60   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 62   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 75   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 76   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 78   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 81   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# 83   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   20
# ..                                                 ...   ...    ...  ...
# 93   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   29
# 112  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   29
# 123  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   29
# 145  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   29
# 2    TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   30
# 5    TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   30
# 7    TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   30
# 14   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   30
# 39   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   30
# 121  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   30
# 129  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   30
# 3    TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 6    TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 15   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 54   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 63   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 70   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 86   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 95   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      5   31
# 115  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   31
# 136  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      5   31
# 13   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 22   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 25   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 56   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 66   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 88   TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 100  TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 105  TwitterData/[ BATCH -at,BernieSanders-STATUS]2...  2016      6    1
# 108  TwitterData/[ BATCH -at,SenSanders-STATUS]2016...  2016      6    1
#
# [147 rows x 4 columns]

# %%
np.unique(sanders_filenames_table.day)
# Out:
# array([ 1, 19, 20, 23, 24, 25, 26, 27, 28, 29, 30, 31])
